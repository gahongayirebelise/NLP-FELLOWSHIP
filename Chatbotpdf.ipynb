# %% [markdown]
# <a href="https://colab.research.google.com/github/gahongayirebelise/NLP-FELLOWSHIP/blob/main/Chatbotpdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 106 kB 29.5 MB/s
# ...
#      |████████████████████████████████| 69 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 43.3 MB/s
# ...
#      |████████████████████████████████| 32.8 MB 56 kB/s
# ...
#      |████████████████████████████████| 5.6 MB 10.4 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 39.7 MB/s
# ...
#      |████████████████████████████████| 128 kB 75.6 MB/s
# ...
#      |████████████████████████████████| 112 kB 86.3 MB/s
# ...
#      |████████████████████████████████| 73 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 149 kB 56.6 MB/s
# ...
#      |████████████████████████████████| 74 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 340 kB 56.1 MB/s
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3980 sha256=a76d88e6fdf4283c20086e30148613d2276a35f2e9e3fce6446e54a0634ac5a9
# ...

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import textract
import os

# %%
path = "/content/gdrive/MyDrive/NLP FELLOWSHIP/National_Investment_Policy_25_April_2017.pdf"
os.chdir("/content/gdrive/MyDrive/NLP FELLOWSHIP/")
# !ls
# Out:
#  belise.py		  National_Investment_Policy_25_April_2017.pdf
#  cleaned_data.csv	  Text_To_Features.ipynb
# 'my_colab_ setup.ipynb'

# %%
text = textract.process('National_Investment_Policy_25_April_2017.pdf')
text = text.decode("utf-8")
with open('National_Investment_Policy_25_April_2017.txt','w+') as f:
  f.writelines((str(text).replace('\n',' ').split('.')))
# print(text)

# %%
print(text)
# Out:
#
#
#
#
#
#
#
#
#
#
# REPUBLIC OF RWANDA
#
#
#
#
#
#
#
#
#
# National Investment Policy
#
# Prepared by
#
# MINECOFIN
#
# April, 2017
#
#
#
#
#
# I
#
# Table of Contents
#
#
#
# Background and Objectives ........................................................................................................ 1
#
# Foundation of the National Investment Policy ........................................................................ 3
#
# 2.1  Definitions, terminology ..................................................................................................... 3
#
# Scope of investment subjects covered ............................................................................... 4
#
# Funding Public Investments ............................................................................................... 5
#
# 3  Guiding principles of the National Investment Policy ........................................................... 7
#
# 4
#
# ...
